# %%
import camelot

# %%
tables = camelot.read_pdf('2.pdf', flavor='stream')
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# /Users/svetlanamargetova/Desktop/camelot/venv/lib/python3.11/site-packages/camelot/parsers/base.py:124: UserWarning: page-1 is image-based, camelot only works on text-based pages.
#   warnings.warn(

# %%
tables
# Out:
# <TableList n=0>

# %%
tables.export('foo.csv', f='csv', compress=True)

# %%
tables[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 tables[0]
#
# File ~/Desktop/camelot/venv/lib/python3.11/site-packages/camelot/core.py:938, in TableList.__getitem__(self, idx)
#     937 def __getitem__(self, idx):  # noqa D105
# --> 938     return self._tables[idx]
#
# IndexError: list index out of range

# %%
tables[0].parsing_report
# Out:
# {'accuracy': 99.58, 'whitespace': 32.69, 'order': 1, 'page': 1}

# %%
tables[0].to_csv('foo.csv')

# %%
tables[0].df
# Out:
#        0                               1  \
# 0                             UN/EDIFACT
# 1                                   Name
# 2    UNB
# 3   S001               SYNTAX IDENTIFIER
# 4   0001               Syntax identifier
# 5   0002           Syntax version number
# 6   S002              INTERCHANGE SENDER
# 7   0004           Sender identification
# 8
# 9
# 10
# 11  0007     Partner identification code
# 12                             qualifier
# 13  0008  Address for reverse routing  C
# 14  S003           INTERCHANGE RECIPIENT
# 15  0010        Recipient identification
# 16
# 17
# 18  0007     Partner identification code
# 19                             qualifier
# 20  0014                 Routing address
# 21  S004                    DATE/TIME OF
# 22                           PREPARATION
# 23  0017             Date of preparation
# 24  0019             Time of preparation
# 25  0020             Interchange control
# 26                             reference
# ...
